# %%
# 1. Install Ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# 2. Start Ollama in the background
# !nohup ollama serve > ollama.log 2>&1 &

# 3. Give it 5 seconds to start, then pull the model
# !sleep 5
# !echo "Downloading the AI Model (This takes a minute or two)..."
# !ollama pull qwen2.5:8b

# 4. Download Cloudflare Tunnel to expose the server to the internet
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64

# 5. Start the tunnel and extract the public URL
# !nohup ./cloudflared-linux-amd64 tunnel --url http://localhost:11434 > tunnel.log 2>&1 &
# !sleep 10
# !echo "========================================="
# !echo "YOUR API URL IS READY:"
# !grep -o 'https://[^[:space:]]*\.trycloudflare\.com' tunnel.log
# !echo "========================================="
# Out:
# >>> Installing ollama to /usr/local
# ERROR: This version requires zstd for extraction. Please install zstd and try again:
#   - Debian/Ubuntu: sudo apt-get install zstd
#   - RHEL/CentOS/Fedora: sudo dnf install zstd
#   - Arch: sudo pacman -S zstd
# ...
# /bin/bash: line 1: ollama: command not found
# ...
# YOUR API URL IS READY:
# https://sports-plays-compilation-sofa.trycloudflare.com
# ...
